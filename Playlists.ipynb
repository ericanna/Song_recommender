# %%
import config

# %%
import spotipy
import json
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= "beba121b335d4a9d95e083d26c5ef644",
                                                           client_secret= "ef6e57241a3d47a6b3ad1400c4ed610e"))

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DX4UtSsGT1Sbe",market="GB")

# %%
import pprint

pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4UtSsGT1Sbe/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2023-02-02T20:37:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XpaIBNiVzIetEPCWDvAFP'},
#                                              'href': 'https://api.spotify.com/v1/artists/6XpaIBNiVzIetEPCWDvAFP',
#                                              'id': '6XpaIBNiVzIetEPCWDvAFP',
# ...

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "37i9dQZF1DX4UtSsGT1Sbe")

# %%
list_of_audio_features=[]

for item in range(0,150):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df1=pd.DataFrame(list_of_audio_features)    
df1=df1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df1
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.709   0.824    -8.824       0.0453       0.20700
# 1           0.920   0.654    -3.051       0.0401       0.02360
# 2           0.724   0.436    -9.321       0.0282       0.57600
# 3           0.573   0.902    -7.638       0.0540       0.01800
# 4           0.583   0.905    -6.132       0.0733       0.09840
# ..            ...     ...       ...          ...           ...
# 145         0.630   0.788    -6.700       0.0298       0.00322
# 146         0.754   0.366   -10.070       0.0312       0.27300
# 147         0.851   0.551    -5.177       0.0396       0.15100
# 148         0.717   0.588   -13.953       0.0535       0.33100
# 149         0.805   0.602    -9.700       0.0579       0.11900
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000307    0.0888    0.867  118.818  2tUBqZG2AbRi7Q0BIrVrEj
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "7tDmQVcqJiYL85F88ygS6K",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "7tDmQVcqJiYL85F88ygS6K")

# %%
list_of_audio_features=[]

for item in range(0,30):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df2=pd.DataFrame(list_of_audio_features)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.700   0.709    -5.006       0.0838       0.00480
# 1          0.549   0.335   -11.421       0.0260       0.39400
# 2          0.365   0.338   -13.406       0.0322       0.73500
# 3          0.683   0.515   -10.932       0.0592       0.13700
# 4          0.347   0.228    -9.667       0.0296       0.90100
# 5          0.308   0.464    -9.032       0.0279       0.41800
# 6          0.806   0.462   -12.778       0.0298       0.78000
# 7          0.664   0.547   -11.594       0.0281       0.13900
# 8          0.741   0.267   -17.204       0.0285       0.25300
# 9          0.675   0.597   -11.329       0.0337       0.05340
# 10         0.480   0.542    -8.510       0.0348       0.34500
# 11         0.540   0.709    -5.539       0.0294       0.02880
# 12         0.489   0.389   -11.653       0.0284       0.87700
# 13         0.546   0.733    -7.073       0.0299       0.03990
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "445WbblV1UABVYuqfJ293n",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "445WbblV1UABVYuqfJ293n")

# %%
list_of_audio_features=[]

for item in range(0,93):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df3=pd.DataFrame(list_of_audio_features)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df3
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.781   0.724    -6.361       0.0284        0.0498
# 1          0.691   0.524    -7.754       0.3070        0.1030
# 2          0.799   0.705    -7.582       0.0698        0.0554
# 3          0.730   0.771    -6.973       0.0534        0.0321
# 4          0.805   0.466    -8.644       0.1810        0.1510
# ..           ...     ...       ...          ...           ...
# 88         0.596   0.307    -8.653       0.0288        0.8930
# 89         0.335   0.251    -6.225       0.0317        0.9240
# 90         0.510   0.106   -12.813       0.0326        0.9360
# 91         0.489   0.597    -6.633       0.0292        0.2700
# 92         0.133   0.510   -10.445       0.0328        0.6060
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000003    0.1630   0.9230  120.009  7GwNDFyxvpHAd4l1IfUDmr
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "1bwMjyhvBpVl108Apbl9X2",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "1bwMjyhvBpVl108Apbl9X2")

# %%
list_of_audio_features=[]

for item in range(0,1461):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df4
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.572   0.949    -4.865       0.0600       0.00165
# 1            0.540   0.821    -3.789       0.0873       0.03970
# 2            0.637   0.690    -4.057       0.0405       0.00786
# 3            0.640   0.637    -5.228       0.0322       0.12900
# 4            0.698   0.854    -3.840       0.0451       0.10100
# ...            ...     ...       ...          ...           ...
# 1456         0.587   0.350   -10.954       0.0318       0.74000
# 1457         0.728   0.734    -3.234       0.0318       0.63000
# 1458         0.734   0.684   -13.822       0.2270       0.25300
# 1459         0.671   0.539    -6.080       0.0392       0.18000
# 1460         0.678   0.575    -4.896       0.0565       0.39300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000195    0.1630    0.530  118.974  0nYvjcSlCgjcwogQAwIwNp
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "7hTiubqJadHBJ6qlURaiO2",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "7hTiubqJadHBJ6qlURaiO2")

# %%
list_of_audio_features=[]

for item in range(0,151):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df5=pd.DataFrame(list_of_audio_features)    
df5=df5[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df5
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.694   0.397   -13.417       0.0533       0.22800
# 1           0.743   0.891    -3.474       0.0573       0.09580
# 2           0.838   0.870    -2.655       0.1040       0.00629
# 3           0.758   0.523   -11.876       0.0792       0.67300
# 4           0.361   0.601   -11.426       0.0466       0.37300
# ..            ...     ...       ...          ...           ...
# 146         0.556   0.315    -7.754       0.0699       0.96800
# 147         0.780   0.746    -5.508       0.0429       0.16700
# 148         0.671   0.541   -11.176       0.0497       0.23100
# 149         0.668   0.876    -8.133       0.0409       0.14300
# 150         0.715   0.867    -8.954       0.1420       0.48900
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.110000    0.1300    0.681   89.894  00oiWMdqxFIWDD6HjoasNA
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "5Rrf7mqN8uus2AaQQQNdc1",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "5Rrf7mqN8uus2AaQQQNdc1")

# %%
list_of_audio_features=[]

for item in range(0,500):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df6=pd.DataFrame(list_of_audio_features)    
df6=df6[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df6
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.482   0.721    -6.839       0.0321       0.73100
# 1           0.723   0.863    -7.890       0.0338       0.03830
# 2           0.547   0.257   -12.358       0.0252       0.90700
# 3           0.367   0.452   -10.422       0.0307       0.03530
# 4           0.283   0.716    -9.632       0.0986       0.44700
# ..            ...     ...       ...          ...           ...
# 495         0.539   0.969    -3.713       0.0780       0.10400
# 496         0.512   0.253   -15.793       0.0391       0.41700
# 497         0.449   0.700    -9.777       0.0466       0.21600
# 498         0.735   0.653    -5.533       0.0269       0.20200
# 499         0.377   0.681    -8.039       0.0298       0.00088
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1890    0.557   95.263  3AhXZa8sUQht0UEdBJgpGc
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "4N8gA9qz14KClL65uJlnqX",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "4N8gA9qz14KClL65uJlnqX")

# %%
list_of_audio_features=[]

for item in range(0,426):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df7=pd.DataFrame(list_of_audio_features)    
df7=df7[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df7
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.624   0.591    -7.884       0.0287      0.001860
# 1           0.257   0.964    -4.709       0.1270      0.000318
# 2           0.247   0.946    -5.541       0.1560      0.102000
# 3           0.791   0.733    -5.465       0.0633      0.523000
# 4           0.418   0.946    -3.504       0.0583      0.027300
# ..            ...     ...       ...          ...           ...
# 421         0.601   0.466   -12.661       0.1340      0.069100
# 422         0.623   0.782    -9.161       0.0284      0.099800
# 423         0.692   0.598    -7.893       0.0373      0.464000
# 424         0.370   0.515    -9.487       0.0321      0.023300
# 425         0.374   0.356   -12.381       0.0345      0.831000
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.082000    0.0895    0.835  118.410  4dWlES2BxfKjEv1PkAG6CJ
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "0lNwm5xFEgRx4iDP2DLx3j",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "0lNwm5xFEgRx4iDP2DLx3j")

# %%
list_of_audio_features=[]

for item in range(0,1000):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df8=pd.DataFrame(list_of_audio_features)    
df8=df8[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df8
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.547   0.257   -12.358       0.0252       0.90700
# 1           0.249   0.660    -6.905       0.0342       0.50400
# 2           0.539   0.690    -9.019       0.0332       0.08300
# 3           0.521   0.487    -7.525       0.0299       0.25300
# 4           0.149   0.206   -13.888       0.0323       0.82200
# ..            ...     ...       ...          ...           ...
# 995         0.706   0.713    -5.512       0.0301       0.05960
# 996         0.800   0.563   -10.209       0.0303       0.05100
# 997         0.664   0.660    -6.526       0.1300       0.44700
# 998         0.336   0.627    -7.463       0.0384       0.16400
# 999         0.556   0.864    -5.870       0.0584       0.00958
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.183000    0.0935    0.169   75.752  7pKfPomDEeI4TPT6EOYjn9
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "6VzBJrKIVKoYgHVsBJ8uzh",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "6VzBJrKIVKoYgHVsBJ8uzh")

# %%
list_of_audio_features=[]

for item in range(0,952):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df9=pd.DataFrame(list_of_audio_features)    
df9=df9[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df9
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.712   0.735    -8.960       0.0394       0.00485
# 1           0.421   0.195   -13.677       0.0317       0.92500
# 2           0.517   0.421   -10.772       0.0321       0.25200
# 3           0.396   0.473    -7.670       0.0345       0.32600
# 4           0.429   0.543    -9.139       0.0347       0.53600
# ..            ...     ...       ...          ...           ...
# 947         0.546   0.748   -13.989       0.0384       0.50500
# 948         0.769   0.508   -13.279       0.1080       0.17200
# 949         0.865   0.855    -3.470       0.0917       0.02070
# 950         0.218   0.628    -7.699       0.0339       0.73800
# 951         0.477   0.360   -13.210       0.0524       0.92900
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000379    0.1190    0.840  120.678  4FmgEsVgrK5GG6bzdgXzrV
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DWX4CmhTadwuL",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "37i9dQZF1DWX4CmhTadwuL")

# %%
list_of_audio_features=[]

for item in range(0,100):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df10=pd.DataFrame(list_of_audio_features)    
df10=df10[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df10
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.568   0.574    -8.993       0.0683         0.468
# 1          0.674   0.419   -12.413       0.2680         0.747
# 2          0.654   0.514   -12.432       0.0413         0.684
# 3          0.448   0.788    -8.697       0.0513         0.780
# 4          0.605   0.542    -7.849       0.0380         0.680
# ..           ...     ...       ...          ...           ...
# 95         0.500   0.685   -10.372       0.0369         0.501
# 96         0.674   0.843    -9.039       0.0640         0.509
# 97         0.576   0.589   -12.233       0.0870         0.362
# 98         0.618   0.618   -13.717       0.0446         0.198
# 99         0.638   0.718    -9.532       0.1430         0.736
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.3620    0.680  107.821  2GAFZG9Z7UGS1iMm4Idrnr
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "0QLOSleHXvNO1m4UYBcoti",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "0QLOSleHXvNO1m4UYBcoti")

# %%
list_of_audio_features=[]

for item in range(0,359):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df11=pd.DataFrame(list_of_audio_features)    
df11=df11[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df11
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.240   0.277   -14.557       0.0458       0.92300
# 1           0.359   0.367    -7.684       0.0335       0.73800
# 2           0.786   0.729    -5.931       0.0536       0.00774
# 3           0.515   0.664    -7.032       0.0647       0.01860
# 4           0.264   0.286   -15.193       0.0344       0.90100
# ..            ...     ...       ...          ...           ...
# 354         0.812   0.341    -8.688       0.0451       0.03030
# 355         0.534   0.724    -7.342       0.0427       0.33000
# 356         0.652   0.622    -5.293       0.0406       0.11300
# 357         0.267   0.376    -8.655       0.0301       0.16300
# 358         0.510   0.653    -8.622       0.0335       0.26200
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.856000    0.2330   0.0371  125.489  3efGEN6W4edIFdN7SmuCLN
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "10wb2RWXZEBkRcgges4Whs",market="GB")

# %%
tracks=get_playlist_tracks("spotify", "10wb2RWXZEBkRcgges4Whs")

# %%
list_of_audio_features=[]

for item in range(0,500):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df12=pd.DataFrame(list_of_audio_features)    
df12=df12[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df12
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.805   0.558    -5.226       0.0410      0.164000
# 1           0.797   0.582   -12.970       0.2550      0.004840
# 2           0.212   0.383   -10.071       0.0347      0.723000
# 3           0.482   0.721    -6.839       0.0321      0.731000
# 4           0.502   0.912    -4.556       0.0564      0.000025
# ..            ...     ...       ...          ...           ...
# 495         0.381   0.186   -15.477       0.0290      0.613000
# 496         0.715   0.624    -3.046       0.1140      0.110000
# 497         0.257   0.453    -8.063       0.0305      0.440000
# 498         0.595   0.643    -9.275       0.0365      0.760000
# 499         0.617   0.717    -7.858       0.1530      0.005640
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000022    0.0546    0.965  114.950  7s25THrKz86DM225dOYwnr
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "3lVzlSt4PkFeBkot8DMlTZ",market="GB")
tracks=get_playlist_tracks("spotify", "3lVzlSt4PkFeBkot8DMlTZ")

# %%
list_of_audio_features=[]

for item in range(0,492):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df13=pd.DataFrame(list_of_audio_features)    
df13=df13[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df13
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.282   0.932    -4.701       0.0387      0.120000
# 1           0.429   0.661    -7.227       0.0281      0.002390
# 2           0.277   0.663    -8.821       0.0377      0.000409
# 3           0.535   0.948    -4.190       0.0356      0.002250
# 4           0.412   0.920    -4.852       0.0575      0.000456
# ..            ...     ...       ...          ...           ...
# 487         0.378   0.925    -3.781       0.1850      0.023400
# 488         0.531   0.915    -4.237       0.0369      0.011900
# 489         0.587   0.566    -9.932       0.0276      0.469000
# 490         0.494   0.936    -7.195       0.0401      0.011200
# 491         0.556   0.315   -11.651       0.0625      0.568000
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.033500    0.0692    0.536  190.080  01wsKcJ8ptqUmatpJlEGYj
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "1owpknl4g1W8Y77cn1E47e",market="GB")
tracks=get_playlist_tracks("spotify", "1owpknl4g1W8Y77cn1E47e")

# %%
list_of_audio_features=[]

for item in range(0,601):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df14=pd.DataFrame(list_of_audio_features)    
df14=df14[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df14
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.740   0.574    -6.938       0.2450       0.41100
# 1           0.606   0.809    -4.667       0.2790       0.00778
# 2           0.465   0.735    -3.715       0.1170       0.07110
# 3           0.617   0.717    -7.858       0.1530       0.00564
# 4           0.744   0.589    -1.218       0.0359       0.36000
# ..            ...     ...       ...          ...           ...
# 596         0.688   0.647    -7.258       0.1900       0.00815
# 597         0.703   0.557    -6.798       0.0438       0.01160
# 598         0.768   0.446    -7.659       0.0292       0.52000
# 599         0.781   0.594    -6.959       0.0485       0.01360
# 600         0.629   0.692    -8.045       0.0376       0.00981
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.2620   0.3300  149.762  5Pt83OUaK3K9C2if4C5JOk
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "2DqpNV8w7tgngbJWQD9wS4",market="GB")
tracks=get_playlist_tracks("spotify", "2DqpNV8w7tgngbJWQD9wS4")

# %%
list_of_audio_features=[]

for item in range(0,500):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df15=pd.DataFrame(list_of_audio_features)    
df15=df15[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df15
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.659   0.802    -4.790       0.1480        0.2080
# 1           0.723   0.777    -3.503       0.1080        0.0426
# 2           0.821   0.688    -6.783       0.0538        0.4620
# 3           0.852   0.773    -2.921       0.0776        0.1870
# 4           0.826   0.773    -4.218       0.0524        0.3230
# ..            ...     ...       ...          ...           ...
# 495         0.720   0.766    -7.701       0.0482        0.1210
# 496         0.760   0.646    -5.048       0.4330        0.2330
# 497         0.864   0.497    -8.886       0.1800        0.0736
# 498         0.965   0.633    -6.392       0.1010        0.0208
# 499         0.574   0.891    -3.665       0.1570        0.0847
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1230    0.863  177.936  7CUYHcu0RnbOnMz4RuN07w
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "5FtC9xj0kOHjneV4zlJZ46",market="GB")
tracks=get_playlist_tracks("spotify", "5FtC9xj0kOHjneV4zlJZ46")

# %%
list_of_audio_features=[]

for item in range(0,525):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df16=pd.DataFrame(list_of_audio_features)    
df16=df16[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df16
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0          0.0819  0.1340   -21.521       0.0410        0.8540
# 1          0.1700  0.4060   -12.009       0.0383        0.3710
# 2          0.1590  0.1850   -20.721       0.0488        0.4020
# 3          0.1550  0.0223   -34.178       0.0474        0.7610
# 4          0.1910  0.0633   -28.951       0.0408        0.6450
# ..            ...     ...       ...          ...           ...
# 520        0.0671  0.0777   -24.175       0.0424        0.9110
# 521        0.2860  0.0968   -16.806       0.0323        0.1780
# 522        0.2110  0.5700   -11.200       0.0515        0.0191
# 523        0.2590  0.5320    -8.953       0.0380        0.0709
# 524        0.1750  0.3990   -14.865       0.0501        0.4730
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0               0.912    0.1230   0.0374   81.592  4vJkgZIeyiIdaNgyc7StaC
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "3aFd9gQe85uUsTIFEVal0S",market="GB")
tracks=get_playlist_tracks("spotify", "3aFd9gQe85uUsTIFEVal0S")

# %%
list_of_audio_features=[]

for item in range(0,500):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df17=pd.DataFrame(list_of_audio_features)    
df17=df17[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df17
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.617   0.717    -7.858       0.1530      0.005640
# 1           0.595   0.643    -9.275       0.0365      0.760000
# 2           0.257   0.453    -8.063       0.0305      0.440000
# 3           0.715   0.624    -3.046       0.1140      0.110000
# 4           0.381   0.186   -15.477       0.0290      0.613000
# ..            ...     ...       ...          ...           ...
# 495         0.502   0.912    -4.556       0.0564      0.000025
# 496         0.482   0.721    -6.839       0.0321      0.731000
# 497         0.212   0.383   -10.071       0.0347      0.723000
# 498         0.797   0.582   -12.970       0.2550      0.004840
# 499         0.805   0.558    -5.226       0.0410      0.164000
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.4080    0.490  103.992  0j2T0R9dR9qdJYsB7ciXhf
# ...

# %%
df=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17], axis = 0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index()
# Out:
#       index  danceability  energy  loudness  speechiness  acousticness  \
# 0         0         0.709   0.824    -8.824       0.0453        0.2070
# 1         1         0.920   0.654    -3.051       0.0401        0.0236
# 2         2         0.724   0.436    -9.321       0.0282        0.5760
# 3         3         0.573   0.902    -7.638       0.0540        0.0180
# 4         4         0.583   0.905    -6.132       0.0733        0.0984
# ...     ...           ...     ...       ...          ...           ...
# 6772    431         0.440   0.528    -7.809       0.0317        0.0171
# 6773    435         0.694   0.831    -7.288       0.0301        0.1650
# 6774    468         0.889   0.818    -4.639       0.2530        0.4700
# 6775    472         0.646   0.880    -7.753       0.0637        0.0623
# 6776    485         0.496   0.703    -6.905       0.0376        0.5250
#
#       instrumentalness  liveness  valence    tempo                      id  \
# ...

# %%
df.to_csv(songs.csv")
