# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.billboard.com/charts/hot-100/"

# %%
response = requests.get(url)

# %%
response.status_code #checking for errors
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
songs = [elem.get_text().replace("\n","").replace("\t","") for elem in soup.select(".c-title.a-no-trucate.a-font-primary-bold-s")]

# %%
songs
# Out:
# ['Flowers',
#  'Kill Bill',
#  "Creepin'",
#  'Anti-Hero',
#  'Unholy',
#  'Die For You',
#  "I'm Good (Blue)",
#  'Rich Flex',
#  'As It Was',
#  'Just Wanna Rock',
#  'Made You Look',
#  'Golden Hour',
#  'Under The Influence',
#  'Something In The Orange',
#  'Cuff It',
#  'Rock And A Hard Place',
#  'Thank God',
#  'You Proof',
#  'Lavender Haze',
#  'Bad Habit',
#  'Thought You Should Know',
#  'Bzrp Music Sessions, Vol. 53',
#  'Escapism',
#  'Going, Going, Gone',
#  'Superhero (Heroes & Villains)',
#  'Calm Down',
#  'Last Night',
#  'Until I Found You',
#  'Wait In The Truck',
#  'The Kind Of Love We Make',
#  'I Like You (A Happier Song)',
#  'Shirt',
#  'Heart Like A Truck',
#  'Wait For U',
#  'Snooze',
#  'Sure Thing',
#  'Bebe Dame',
#  'Players',
#  'Tomorrow 2',
#  'Love Again',
#  'She Had Me At Heads Carolina',
#  'Dawns',
#  'Whiskey On You',
#  'Super Freaky Girl',
#  'Nobody Gets Me',
#  'Unstoppable',
#  'What My World Spins Around',
#  'Sunroof',
# ...

# %%
artists = [elem.get_text().replace("\n", "").replace("\t", "") for elem in soup.select(".c-label.a-no-trucate.a-font-primary-s")]

# %%
artists
# Out:
# ['Miley Cyrus',
#  'SZA',
#  'Metro Boomin, The Weeknd & 21 Savage',
#  'Taylor Swift',
#  'Sam Smith & Kim Petras',
#  'The Weeknd',
#  'David Guetta & Bebe Rexha',
#  'Drake & 21 Savage',
#  'Harry Styles',
#  'Lil Uzi Vert',
#  'Meghan Trainor',
#  'JVKE',
#  'Chris Brown',
#  'Zach Bryan',
#  'Beyonce',
#  'Bailey Zimmerman',
#  'Kane Brown With Katelyn Brown',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Steve Lacy',
#  'Morgan Wallen',
#  'Bizarrap & Shakira',
#  'RAYE Featuring 070 Shake',
#  'Luke Combs',
#  'Metro Boomin, Future & Chris Brown',
#  'Rema & Selena Gomez',
#  'Morgan Wallen',
#  'Stephen Sanchez',
#  'HARDY Featuring Lainey Wilson',
#  'Luke Combs',
#  'Post Malone Featuring Doja Cat',
#  'SZA',
#  'Lainey Wilson',
#  'Future Featuring Drake & Tems',
#  'SZA',
#  'Miguel',
#  'Fuerza Regida X Grupo Frontera',
#  'Coi Leray',
#  'GloRilla & Cardi B',
#  'The Kid LAROI',
#  'Cole Swindell',
#  'Zach Bryan Featuring Maggie Rogers',
#  'Nate Smith',
# ...

# %%
hot_100 = pd.DataFrame({"Song": songs, "Artist": artists})

# %%
hot_100
# Out:
#                            Song                                Artist
# 0                       Flowers                           Miley Cyrus
# 1                     Kill Bill                                   SZA
# 2                      Creepin'  Metro Boomin, The Weeknd & 21 Savage
# 3                     Anti-Hero                          Taylor Swift
# 4                        Unholy                Sam Smith & Kim Petras
# ..                          ...                                   ...
# 95                      Hey Mor                  Ozuna Featuring Feid
# 96                Gato de Noche                Nengo Flow & Bad Bunny
# 97               Heart To Heart                           Mac DeMarco
# 98  Never Gonna Not Dance Again                                  P!nk
# 99       Dancin' In The Country                         Tyler Hubbard
#
# [100 rows x 2 columns]
